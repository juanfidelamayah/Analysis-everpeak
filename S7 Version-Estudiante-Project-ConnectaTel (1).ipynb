# %% [markdown]
# Hola Juan!
#
# Soy **Juan Pablo Pérez** - **especialista en IA y Ciencia de Datos, instructor y ahora también tu revisor de proyecto**.
#
# Antes de comenzar, quiero que sepas algo importante: mi objetivo no es encontrar errores, sino ayudarte a desarrollar la mentalidad de un profesional de datos.
#
# Durante esta revisión encontrarás diferentes tipos de comentarios, observaciones basadas en situaciones reales que suelen encontrarse en proyectos profesionales de análisis de datos, machine learning e inteligencia artificial.
#
# Mi filosofía como revisor es sencilla:
#
# **Cada proyecto es una oportunidad para entrenar algo: un modelo, una habilidad o una forma de pensar.**
#
# Por ello, intentaré guiarte con preguntas, pistas y observaciones antes de darte una solución directa. El objetivo es que cada corrección se convierta en aprendizaje.
#
# Gracias por tu esfuerzo y dedicación. Ahora sí, vamos a revisar tu proyecto!
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor [#° iteración]</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b>
#
# Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor [#° iteración]</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b>
#
# Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor [#° iteración]</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b>
#
# Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# En cada revisión, recibirás un **Comentario General del Revisor** que puede incluir:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
#
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
#
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
# También puedes responderme copiando el siguiente bloque y colocando ahí tu mensaje si tienes alguna duda o quieres aclarar algo específico:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante [#° iteración]</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
# **Empecemos!**
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario General del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
#
# Juan, en esta parte encontrarás una apreciación general de tu proyecto para que a partir de allí nos vayamos punto por punto. Primero que nada, espero que este camino en el mundo de los datos esté siendo sumamente interesante y retador para ti. Cada dataset es una historia esperando ser contada, y en este proyecto has demostrado una gran capacidad para descifrarla.<br><br>
# Respecto a tu trabajo en esta primera iteración, quiero felicitarte por la solidez de tu análisis. Has abordado el preprocesamiento de datos con un excelente criterio técnico, identificando correctamente los valores faltantes aleatorios condicionales (MAR) y resolviendo de manera impecable los valores sentinels en la edad y las ciudades. Además, tu propuesta de segmentación utilizando np.select muestra un gran dominio de la biblioteca NumPy, y tu análisis ejecutivo final es sumamente estructurado y orientado al negocio.<br><br>
# Hay algunos detalles técnicos menores que debemos ajustar, como un error de copiado en la exploración de usage, la incorporación del parámetro hue en tus histogramas y un detalle de sintaxis con el enlace de GitHub. Estoy seguro de que los resolverás rápidamente para dejar tu proyecto impecable. Sigue adelante, vas por un excelente camino!<br><br>
# Aspectos destacados:<br>
# - Excelente diagnóstico y justificación de los valores faltantes tipo MAR.<br>
# - Uso eficiente de np.select para realizar la segmentación de clientes.<br>
# - Redacción de un análisis ejecutivo muy completo y con recomendaciones de negocio accionables.
# </div>

# %% [markdown]
# # Análisis ConnectaTel
#
# Como **analista de datos**, tu objetivo es evaluar el **comportamiento de los clientes** de una empresa de telecomunicaciones en Latinoamérica, ConnectaTel.
#
# Trabajaremos con información registrada **hasta el año 2024**, lo cual permitirá analizar el comportamiento del negocio dentro de ese periodo.
#
# Para ello trabajarás con tres datasets:
#
# - **plans.csv** → información de los planes actuales (precio, minutos incluidos, GB incluidos, costo por extra)
# - **users.csv** → información de los clientes (edad, ciudad, fecha de registro, plan, churn)
# - **usage.csv** → detalle del **uso real** de los servicios (llamadas y mensajes)
#
# Deberás **explorar**, **limpiar** y **analizar** estos datos para construir un **perfil estadístico** de los clientes, detectar **comportamientos atípicos** y crear **segmentos de clientes**.
#
# Este análisis te permitirá **identificar patrones de consumo**, **diseñar estrategias de retención** y **sugerir mejoras en los planes** ofrecidos por la empresa.
#
# > 💡 Antes de empezar, recuerda pensar de forma **programática**: ¿qué pasos necesitas? ¿En qué orden? ¿Qué quieres medir y por qué?

# %% [markdown]
# ---
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de los tres datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯 Objetivo:**
# Tener los **3 datasets listos en memoria**, entender su contenido y realizar una revisión preliminar.
#
# **Instrucciones:**
# - Importa las librerías necesarias (por ejemplo `pandas`, `seaborn`, `matplotlib.pyplot`)
# - Carga los archivos CSV usando `pd.read_csv()`:
#   - **`/datasets/plans.csv`**
#   - **`/datasets/users_latam.csv`**
#   - **`/datasets/usage.csv`**
# - Guarda los DataFrames en las variables: `plans`, `users`, `usage`.
# - Muestra las primeras filas de cada DataFrame usando `.head()`.

# %%
# importar libreimport pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# cargar archivos
plans = pd.read_csv('/datasets/plans.csv')
users = pd.read_csv('/datasets/users_latam.csv')
usage = pd.read_csv('/datasets/usage.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Excelente carga de los tres conjuntos de datos. Es una buena práctica almacenar cada archivo en variables claras y descriptivas desde el inicio del proyecto.
# </div>

# %%
plans.head()# mostrar las primeras 5 filas de plans
# Out:
#   plan_name  messages_included  gb_per_month  minutes_included  \
# 0    Basico                100             5               100
# 1   Premium                500            20               600
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# 0               12         1.2             0.08            0.10
# 1               25         1.0             0.05            0.07

# %%
users.head()# mostrar las primeras 5 filas de users
# Out:
#    user_id first_name last_name  age      city                       reg_date  \
# 0    10000     Carlos    Garcia   38  Medellín  2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres   53         ?  2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez   57      CDMX  2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez   69    Bogotá  2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres   63       GDL  2022-01-02 02:17:11.657914478
#
#       plan churn_date
# 0   Basico        NaN
# 1   Basico        NaN
# 2   Basico        NaN
# 3  Premium        NaN
# 4   Basico        NaN

# %%
usage.head()# mostrar las primeras 5 filas de usage
# Out:
#    id  user_id  type                           date  duration  length
# 0   1    10332  call  2024-01-01 00:00:00.000000000      0.09     NaN
# 1   2    11458  text  2024-01-01 00:06:30.969774244       NaN    39.0
# 2   3    11777  text  2024-01-01 00:13:01.939548488       NaN    36.0
# 3   4    10682  call  2024-01-01 00:19:32.909322733      1.53     NaN
# 4   5    12742  call  2024-01-01 00:26:03.879096977      4.84     NaN

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ### 1.2 Exploración de la estructura de los datasets
#
# **🎯 Objetivo:**
# Conocer la **estructura de cada dataset**, revisar cuántas filas y columnas tienen, identificar los **tipos de datos** de cada columna y detectar posibles **inconsistencias o valores nulos** antes de iniciar el análisis.
#
# **Instrucciones:**
# - Revisa el **número de filas y columnas** de cada dataset usando `.shape`.
# - Usa `.info()` en cada DataFrame para obtener un **resumen completo** de columnas, tipos de datos y valores no nulos.

# %%
# revisar el número de filas y columnas de cada dataset
print("plans", plans.shape)
print("users", users.shape)
print("usage", usage.shape)
# Out:
# plans (2, 8)
# users (4000, 8)
# usage (40000, 6)

# %%
plans.info()# inspección de plans con .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   plan_name          2 non-null      object
#  1   messages_included  2 non-null      int64
#  2   gb_per_month       2 non-null      int64
#  3   minutes_included   2 non-null      int64
#  4   usd_monthly_pay    2 non-null      int64
#  5   usd_per_gb         2 non-null      float64
#  6   usd_per_message    2 non-null      float64
#  7   usd_per_minute     2 non-null      float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 256.0+ bytes

# %%
users.info()# inspección de users con .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     4000 non-null   int64
#  1   first_name  4000 non-null   object
#  2   last_name   4000 non-null   object
#  3   age         4000 non-null   int64
#  4   city        3531 non-null   object
#  5   reg_date    4000 non-null   object
#  6   plan        4000 non-null   object
#  7   churn_date  466 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 250.1+ KB

# %%
usage.info()# inspección de usage con .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        40000 non-null  int64
#  1   user_id   40000 non-null  int64
#  2   type      40000 non-null  object
#  3   date      39950 non-null  object
#  4   duration  17924 non-null  float64
#  5   length    22104 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Identificación de problemas de calidad de datos
#
# ### 2.1 Revisión de valores nulos
#
# **🎯 Objetivo:**
# Detectar la presencia y magnitud de valores faltantes para evaluar si afectan el análisis o requieren imputación/eliminación.
#
# **Instrucciones:**
# - Cuenta valores nulos por columna para cada dataset.
# - Calcula la proporción de nulos por columna para cada dataset.
#
# El dataset `plans` solamente tiene 2 renglones y se puede observar que no tiene ausentes, por ello no necesita exploración adicional.
#
# <br>
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa `.isna().sum()` para contar valores nulos y usa `.isna().mean()` para calcular la proporción.

# %%
# cantidad de nulos para users
print("Cantidad de valores nulos en users:\n", users.isna().sum())# Cantidad de valores nulos
print("\nProporción de valores nulos en users:\n", users.isna().mean())# Proporción de valores nulos
# Out:
# Cantidad de valores nulos en users:
#  user_id          0
# first_name       0
# last_name        0
# age              0
# city           469
# reg_date         0
# plan             0
# churn_date    3534
# dtype: int64
#
# Proporción de valores nulos en users:
#  user_id       0.00000
# first_name    0.00000
# last_name     0.00000
# age           0.00000
# city          0.11725
# reg_date      0.00000
# plan          0.00000
# churn_date    0.88350
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Muy buen uso de los métodos isna().sum() e isna().mean() para dimensionar tanto la cantidad absoluta como la proporción de valores faltantes. Esto te da un panorama muy claro de la calidad de los datos.
# </div>

# %%
# cantidad de nulos para usage
print("Cantidad de valores nulos en usage:\n", usage.isna().sum())
print("\nProporción de valores nulos en usage:\n", usage.isna().mean())
# Out:
# Cantidad de valores nulos en usage:
#  id              0
# user_id         0
# type            0
# date           50
# duration    22076
# length      17896
# dtype: int64
#
# Proporción de valores nulos en usage:
#  id          0.00000
# user_id     0.00000
# type        0.00000
# date        0.00125
# duration    0.55190
# length      0.44740
# dtype: float64

# %% [markdown]
# ✍️ **Comentario**: Haz doble clic en este bloque y escribe tu diagnóstico al final del bloque. Incluye qué ves y que acción recomendarías para cada caso.
#
# 💡 **Nota:** Justifica tus decisiones brevemente (1 línea por caso).
# * Hint:
#  - Si una columna tiene **más del 80–90% de nulos**, normalmente se **ignora o elimina**.
#  - Si tiene **entre 5% y 30%**, generalmente se **investiga para imputar o dejar como nulos**.
#  - Si es **menor al 5%**, suele ser un caso simple de imputación o dejar como nulos.
#
#  ---
#
# **Valores nulos**
# - ¿Qué columnas tienen valores faltantes y en qué proporción?
# - Indica qué harías: ¿imputar, eliminar, ignorar?
#
# **1. Diagnóstico de valores faltantes por columna y proporción:**
# En el dataset users:
#
# **churn_date (88.35% de nulos / 3,534 filas):** Presenta una alta proporción de nulos debido a que representan a los usuarios que siguen activos en el servicio.
#
# **city (11.72% de nulos / 469 filas):** Presenta una proporción moderada de datos no registrados.
#
# **En el dataset usage:**
#
# **duration (55.19% de nulos / 22,076 filas):** Falta en más de la mitad de los registros.
#
# **length (44.74% de nulos / 17,896 filas):** Falta en casi la mitad de los registros.
#
# **date (0.125% de nulos / 50 filas):** Proporción insignificante de registros sin fecha.
#
# ----
# **2. Plan de acción recomendado (Acción a tomar):** en este caso, se recomienda
#
# **churn_date → Ignorar / Mantener nulos:** Es un comportamiento esperado del negocio; los nulos indican simplemente que el usuario no ha cancelado la cuenta.
#
# **city → Mantener como NA / Imputar como "Desconocido":** Como representa cerca del 11%, imputar o dejar una categoría 'Desconocido' permite conservar el resto de la información del cliente sin perder registros.
#
# **duration → Ignorar / Mantener nulos:** Es un caso de valor faltante aleatorio condicional (MAR, Missing At Random); los nulos corresponden a eventos de mensajes de texto (text), los cuales no poseen duración de llamada.
#
# **length → Ignorar / Mantener nulos:** Es un caso de MAR; los nulos corresponden a eventos de llamadas (call), las cuales no tienen longitud de caracteres.
#
# **date → Eliminar filas o ignorar:** Representa menos del 0.2% de los datos, por lo que eliminar estas filas o dejarlas vacías no afecta estadísticamente al dataset.

# %% [markdown]
# ### 2.2 Detección de valores inválidos y sentinels
#
# 🎯 **Objetivo:**
# Identificar sentinels: valores que no deberían estar en el dataset.
#
# **Instrucciones:**
# - Explora las columnas numéricas con **un resumen estadístico** y describe brevemente que encontraste.
# - Explora las columnas categóricas **relevantes**, revisando sus valores únicos y describe brevemente que encontraste.
#
#
# El dataset `plans` solamente tiene 2 renglones, por ello no necesita exploración adicional.

# %%
users[['user_id', 'age']].describe()# explorar columnas numéricas de users
# Out:
#             user_id          age
# count   4000.000000  4000.000000
# mean   11999.500000    33.739750
# std     1154.844867   123.232257
# min    10000.000000  -999.000000
# 25%    10999.750000    32.000000
# 50%    11999.500000    47.000000
# 75%    12999.250000    63.000000
# max    13999.000000    79.000000

# %% [markdown]
# Notamos lo siguiente:
#
# **- La columna user_id:** Presenta identificadores secuenciales válidos que van desde 10000 hasta 13999, sin valores anómalos o fuera de rango.
#
# **- La columna age:** Presenta un valor mínimo de -999, lo cual es un valor inválido (un sentinel o código de error utilizado para registrar datos faltantes). La media se ve distorsionada por este valor, mientras que el valor máximo es de 79 años.

# %%
usage[['duration', 'length']].describe()# explorar columnas numéricas de usage
# Out:
#            duration        length
# count  17924.000000  22104.000000
# mean       5.202237     52.127398
# std        6.842701     56.611183
# min        0.000000      0.000000
# 25%        1.437500     37.000000
# 50%        3.500000     50.000000
# 75%        6.990000     64.000000
# max      120.000000   1490.000000

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver</b>
#
# Aquí ocurrió un pequeño desliz al copiar y pegar. El comentario indica que vas a explorar las columnas numéricas de usage, pero el código vuelve a ejecutar el describe sobre el dataframe users. ¿Podrías corregir el código para analizar las variables numéricas de usage?
# </div>

# %% [markdown]
# Observamos que:
# **- Las columnas id y user_id:** id es una secuencia numérica válida sin faltantes que identifica cada evento de uso, mientras que user_id vincula correctamente la actividad con los usuarios registrados (IDs entre 10000 y 13999).
#
# **- Las columnas duration y length:** duration presenta valores de duración de llamadas en minutos con un rango que va desde 0.0 hasta valores más elevados, mientras que length representa la cantidad de caracteres en mensajes de texto. Ambas variables muestran una alta cantidad de valores nulos esperados debido al tipo de evento (MAR).

# %%
# explorar columnas categóricas de users
columnas_user = ['city', 'plan']
for col in columnas_user:
    print(f"--- {col} ---")
    print(users[col].value_counts(dropna=False))
# Out:
# --- city ---
# Bogotá      808
# CDMX        730
# Medellín    616
# NaN         469
# GDL         450
# Cali        424
# MTY         407
# ?            96
# Name: city, dtype: int64
# --- plan ---
# Basico     2595
# Premium    1405
# Name: plan, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Excelente decisión al incluir dropna=False dentro de value_counts. Esto te permite identificar si existen valores nulos ocultos o categorías no deseadas como el signo de interrogación. Muy bien pensado!
# </div>

# %% [markdown]
# Se puede evidenciar que:
#
# **- La columna city:** Presenta las principales ciudades de México y Colombia (Bogotá, CDMX, Medellín, etc.). Contiene 469 valores nulos (NaN) y 96 registros con el caracter ?, el cual actúa como un sentinel o valor faltante no estandarizado.
#
# **- La columna plan:** Registra el tipo de plan contratado por cada usuario. Está dividida de forma limpia únicamente entre dos categorías: Basico (2,595 usuarios) y Premium (1,405 usuarios), sin valores nulos ni errores de escritura.

# %%
# explorar columna categórica de usage
usage['type'].value_counts(dropna=False) # completa el código
# Out:
# text    22092
# call    17908
# Name: type, dtype: int64

# %% [markdown]
# En la columna type podemos observar que:
#
# **- Valores y Distribución:** Contiene únicamente dos tipos de eventos registrados de forma limpia:
#
# - text (mensajes de texto): 22,092 registros.
#
# - call (llamadas telefónicas): 17,908 registros.
#
# **Calidad de datos:** No presenta valores nulos (NaN) ni valores inválidos/inconsistentes de formato o tipeo.
#
# **Diagnóstico y Acción:** Los datos son totalmente válidos y coherentes. No se requiere ninguna acción de limpieza o imputación sobre esta columna.

# %% [markdown]
# ---
# ✍️ **Comentario**: Haz doble clic en este bloque y escribe tu diagnóstico. Incluye qué ves y que acción recomendarías para cada caso.
#
# **Valores inválidos o sentinels**
# - ¿En qué columnas encontraste valores inválidos o sentinels?
# - ¿Qué acción tomarías?
#
# **Diagnóstico de valores inválidos o sentinels:**
#
# **age (en users):**
# se evidencia que, contiene el valor -999 como mínimo, el cual es un código de error o sentinel para indicar datos faltantes. Este valor distorsiona el promedio de edad del dataset.
#
# **- Acción recomendada:** Reemplazar los valores -999 por la mediana de la edad de los usuarios válidos (aquellos con edad mayor a 0).
#
#
# **city (en users):**
#
# Se observa que, además de los valores nulos (NaN), contiene 96 registros marcados con el símbolo ?, el cual actúa como un sentinel de información no registrada.
#
# **- Acción recomendada:** Reemplazar el caracter "?" por NaN (o pd.NA) para estandarizar todos los valores faltantes bajo un mismo formato y luego conservarlos como 'Desconocido' o nulos.
#
# **(Nota: Las columnas de usage como duration y length no contienen sentinels, sino valores nulos esperados por el tipo de evento [MAR], y la columna plan está limpia con solo dos categorías válidas).**

# %% [markdown]
# ### 2.3 Revisión y estandarización de fechas
#
# **🎯 Objetivo:**
# Asegurar que las columnas de fecha estén correctamente formateadas y detectar años fuera de rango que indiquen errores de captura.
#
# **Instrucciones:**
# - Convierte las columnas de fecha a tipo fecha y asegurate de que el código sea a prueba de errores.
# - Revisa cuántas veces aparece cada año.
# - Identifica fechas imposibles (ej. años futuros o negativos).
#
# Toma en cuenta que tenemos datos registrados hasta el año 2024.

# %%
# Convertir a fecha la columna `reg_date` de users
users['reg_date'] = pd.to_datetime(users['reg_date'], errors='coerce')
users['reg_date'].head()# completa el código
# Out:
# 0   2022-01-01 00:00:00.000000000
# 1   2022-01-01 06:34:17.914478619
# 2   2022-01-01 13:08:35.828957239
# 3   2022-01-01 19:42:53.743435858
# 4   2022-01-02 02:17:11.657914478
# Name: reg_date, dtype: datetime64[ns]

# %%
# Convertir a fecha la columna `date` de usage
usage['date'] = pd.to_datetime(usage['date'], errors='coerce')

# Mostrar el resultado
usage['date'].head()# completa el código
# Out:
# 0   2024-01-01 00:00:00.000000000
# 1   2024-01-01 00:06:30.969774244
# 2   2024-01-01 00:13:01.939548488
# 3   2024-01-01 00:19:32.909322733
# 4   2024-01-01 00:26:03.879096977
# Name: date, dtype: datetime64[ns]

# %%
# Revisar los años presentes en `reg_date` de users
users['reg_date'].dt.year.value_counts(dropna=False)
# Out:
# 2024    1330
# 2023    1316
# 2022    1314
# 2026      40
# Name: reg_date, dtype: int64

# %% [markdown]
# **En reg_date:** Se observa que la mayoría de los registros de fecha de registro corresponden a los años 2022 (1,314), 2023 (1,316) y 2024 (1,330), los cuales son coherentes con la historia del negocio. Sin embargo, existen 40 registros con el año 2026, lo cual representa una fecha imposible/futura (un error de captura o registro), ya que la base de datos contiene información registrada únicamente hasta el año 2024.

# %%
# Revisar los años presentes en `date` de usage
usage['date'].dt.year.value_counts(dropna=False)
# Out:
# 2024.0    39950
# NaN          50
# Name: date, dtype: int64

# %% [markdown]
# **En date (de usage):** Se observa que la gran mayoría de los eventos corresponden al año 2024 (39,950 registros), acompañados por 50 valores nulos (NaN). No existen registros con años futuros o incoherentes en esta columna.

# %% [markdown]
# ✍️ **Comentario**: escribe tu diagnóstico, e incluye **qué acción recomendarías** para cada caso:
#
# **Fechas fuera de rango**
# - ¿Aparecen años imposibles? (años muy viejos o sin transcurrir al momento de guardar los datos)
# - ¿Qué harías con ellas?
#
# **Diagnóstico de Fechas fuera de rango**
# ¿Aparecen años imposibles?
# Sí. En la columna reg_date de la tabla users se identificaron 40 registros con el año 2026, lo cual es una fecha futura/imposible (error de captura o registro) considerando que la base de datos registra operaciones hasta 2024. En la columna date de usage no hay años imposibles.
#
# ¿Qué hacer con ellas?
# Reemplazar las fechas con año superior a 2024 por valores nulos (pd.NaT) para evitar sesgar el análisis temporal y trabajar únicamente con datos reales de la operación.

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Limpieza básica de datos
#
# ### 3.1 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Aplicar reglas de limpieza para reemplazar valores sentinels y corregir fechas imposibles.
#
# **Instrucciones:**
# - En `age`, reemplaza el sentinel **-999** con la mediana.
# - En `city`, reemplaza el sentinel `"?"` por valores nulos (`pd.NA`).
# - Marca como nulas (`pd.NA`) las fechas fuera de rango.

# %%
# Convertir age a tipo numérico (por si acaso hay texto o valores raros)
users['age'] = pd.to_numeric(users['age'], errors='coerce')

# Calcular la mediana únicamente para valores de edad válidos (mayores a 0)
age_mediana = users[users['age'] > 0]['age'].median()

# Reemplazar los valores -999 (o nulos) por la mediana
users['age'] = users['age'].replace(-999, age_mediana).fillna(age_mediana)

# Verificar los cambios
users['age'].describe()
# Out:
# count    4000.000000
# mean       48.136000
# std        17.689919
# min        18.000000
# 25%        33.000000
# 50%        48.000000
# 75%        63.000000
# max        79.000000
# Name: age, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Excelente resolución para el sentinel de la edad! Al calcular la mediana filtrando únicamente los valores mayores a cero, evitas que el valor -999 distorsione la estadística. Es una gran práctica de ingeniería de datos.
# </div>

# %%
# Reemplazar ? por NA en city
users['city'] = users['city'].replace('?', pd.NA)

# Verificar cambios
users['city'].value_counts(dropna=False)
# Out:
# Bogotá      808
# CDMX        730
# Medellín    616
# NaN         565
# GDL         450
# Cali        424
# MTY         407
# Name: city, dtype: int64

# %%
# Marcar fechas futuras como NA para reg_date
users.loc[users['reg_date'].dt.year > 2024, 'reg_date'] = pd.NaT

# Verificar cambios
users['reg_date'].dt.year.value_counts(dropna=False)
# Out:
# 2024.0    1330
# 2023.0    1316
# 2022.0    1314
# NaN         40
# Name: reg_date, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Muy bien resuelto el manejo de las fechas futuras! Reemplazar los años imposibles como 2026 con NaT es la decisión correcta para no sesgar ningún análisis temporal posterior.
# </div>

# %% [markdown]
# ### 3.2 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Decidir qué hacer con los valores nulos según su proporción y relevancia.
#
# **Instrucciones:**
# - Verifica si los nulos en `duration` y `length` son **MAR**(Missing At Random) revisando si dependen de la columna `type`.
#   Si confirmas que son MAR, **déjalos como nulos** y justifica la decisión.

# %%
# Verificación MAR en usage (Missing At Random) para duration
usage.groupby('type')['duration'].apply(lambda x: x.isna().sum())
# Out:
# type
# call        0
# text    22076
# Name: duration, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Brillante comprobación de la hipótesis MAR (Missing At Random). Agrupar por tipo de servicio demuestra de forma matemática que los nulos en duración corresponden al 100% a mensajes de texto, y los nulos en longitud a llamadas. Excelente análisis!
# </div>

# %%
# Verificación MAR en usage (Missing At Random) para length
usage.groupby('type')['length'].apply(lambda x: x.isna().sum())
# Out:
# type
# call    17896
# text        0
# Name: length, dtype: int64

# %% [markdown]
# **Diagnóstico de nulos en duration y length (Missing At Random - MAR):**
#
# **En duration:** Los 22,076 valores nulos corresponden en un 100% a los registros de tipo text (mensajes), debido a que los mensajes de texto no generan duración de llamada.
#
# **En length:** Los 17,896 valores nulos pertenecen en un 100% a los registros de tipo call (llamadas), ya que las llamadas telefónicas no tienen una longitud de caracteres.
#
# **Acción recomendada**
# Se confirma que son valores faltantes aleatorios condicionales (MAR - Missing At Random). No deben imputarse ni eliminarse; la acción correcta es mantenerlos como nulos (NaN), ya que su ausencia obedece de forma coherente a la naturaleza de cada servicio.

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Summary statistics de uso por usuario
#
#
# ### 4.1 Agrupación por comportamiento de uso
#
# 🎯**Objetivo**: Resumir las variables clave de la tabla `usage` **por usuario**, creando métricas que representen su comportamiento real de uso histórico.
#
# **Instrucciones:**:
# 1. Construye una tabla agregada de `usage` por `user_id` que incluya:
# - número total de mensajes
# - número total de llamadas
# - total de minutos de llamadas
#
# 2. Renombra las columnas para que tengan nombres claros:
# - `cant_mensajes`
# - `cant_llamadas`
# - `cant_minutos_llamada`
# 3. Combina esta tabla con `users`.

# %%
# Columnas auxiliares
usage["is_text"] = (usage["type"] == "text").astype(int) #conocer el total de mensajes
usage["is_call"] = (usage["type"] == "call").astype(int) #conocer el total de llamadas


# Agrupar información por usuario
usage_agg = usage.groupby("user_id").agg(
    cant_mensajes=("is_text", "sum"),
    cant_llamadas=("is_call", "sum"),
    cant_minutos_llamada=("duration", "sum")
).reset_index()

# observar resultado
usage_agg.head(3)
# Out:
#    user_id  cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0    10000              7              3                 23.70
# 1    10001              5             10                 33.18
# 2    10002              5              2                 10.74

# %%
# Renombrar columnas
usage_agg = usage_agg.rename(columns={
    'cant_mensajes': 'total_messages',
    'cant_llamadas': 'total_calls',
    'cant_minutos_llamada': 'total_call_minutes'
})

# observar resultado
usage_agg.head(3)
# Out:
#    user_id  total_messages  total_calls  total_call_minutes
# 0    10000               7            3               23.70
# 1    10001               5           10               33.18
# 2    10002               5            2               10.74

# %%
# Combinar la tabla agregada con el dataset de usuarios
user_profile = users.merge(usage_agg, on='user_id', how='left')

# Rellenar con 0 a los usuarios sin registros de uso
user_profile[['total_messages', 'total_calls', 'total_call_minutes']] = user_profile[['total_messages', 'total_calls', 'total_call_minutes']].fillna(0)

user_profile.head(5)
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  total_messages  total_calls  total_call_minutes
# 0   Basico        NaN             7.0          3.0               23.70
# 1   Basico        NaN             5.0         10.0               33.18
# 2   Basico        NaN             5.0          2.0               10.74
# 3  Premium        NaN            11.0          3.0                8.99
# 4   Basico        NaN             4.0          3.0                8.01

# %% [markdown]
# ### 4.2 4.2 Resumen estadístico por usuario durante el 2024
#
# 🎯 **Objetivo:** Analizar las columnas numéricas y categóricas de los usuarios, para identificar rangos, valores extremos y distribución de los datos antes de continuar con el análisis.
#
# **Instrucciones:**
# 1. Para las columnas **numéricas** relevantes, obtén un resumen estadístico (media, mediana, mínimo, máximo, etc.).
# 2. Para la columna **categórica** `plan`, revisa la distribución en **porcentajes** de cada categoría.

# %%
# Resumen estadístico de las columnas numéricas
user_profile.describe()
# Out:
#             user_id          age  total_messages  total_calls  \
# count   4000.000000  4000.000000     4000.000000  4000.000000
# mean   11999.500000    48.136000        5.523000     4.477000
# std     1154.844867    17.689919        2.359738     2.145139
# min    10000.000000    18.000000        0.000000     0.000000
# 25%    10999.750000    33.000000        4.000000     3.000000
# 50%    11999.500000    48.000000        5.000000     4.000000
# 75%    12999.250000    63.000000        7.000000     6.000000
# max    13999.000000    79.000000       17.000000    15.000000
#
#        total_call_minutes
# count         4000.000000
# mean            23.311225
# std             18.169564
# min              0.000000
# 25%             11.107500
# 50%             19.780000
# 75%             31.412500
# max            155.690000

# %%
# Distribución porcentual del tipo de plan
user_profile['plan'].value_counts(normalize=True) * 100
# Out:
# Basico     64.875
# Premium    35.125
# Name: plan, dtype: float64

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Visualización de distribuciones (uso y clientes) y outliers
#
#
# ### 5.1 Visualización de Distribuciones
#
# 🎯 **Objetivo:**
# Entender visualmente cómo se comportan las variables clave tanto de **uso** como de **clientes**, observar si existen diferencias según el tipo de plan, y analizar la **forma de la distribución**.
#
# **Instrucciones:**
# Graficar **histogramas** para las siguientes columnas:
# - `age` (edad de los usuarios)
# - `cant_mensajes`
# - `cant_llamadas`
# - `total_minutos_llamada`
#
# Después de cada gráfico, escribe un **insight** respecto al plan y la variable, por ejemplo:
# - "Dentro del plan Premium, hay mayor proporción de..."
# - "Los usuarios Básico tienden a hacer ... llamadas y enviar ... mensajes."  o "No existe algún patrón."
# - ¿Qué tipo de distribución tiene ? (simétrica, sesgada a la derecha o a la izquierda)
#
# **Hint**
# Para cada histograma,
# - Usa `hue='plan'` para ver cómo varían las distribuciones según el plan (Básico o Premium).
# - Usa `palette=['skyblue','green']`
# - Agrega título y etiquetas

# %%
# Histograma para visualizar la edad (age) por tipo de plan
sns.histplot(
    data=user_profile, 
    x='age', 
    hue='plan', 
    palette=['skyblue', 'green'], 
    kde=True, 
    bins=20, 
    multiple='dodge'
)
plt.title('Distribución de la Edad de los Usuarios por Plan')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver</b>
#
# En las instrucciones se solicitaba comparar las distribuciones según el tipo de plan usando el parámetro hue y una paleta de colores específica. Actualmente tus histogramas de edad, mensajes, llamadas y minutos no diferencian los planes. ¿Cómo podrías incorporar el parámetro hue en histplot para visualizar ambos planes en el mismo gráfico? Inténtalo en los cuatro histogramas.
# </div>

# %% [markdown]
# 💡Insights:
# **Insights: Distribución de la Edad (age)**
# Comportamiento general: La edad de los usuarios abarca de manera continua desde los 18 hasta los 80 años, con una presencia constante de clientes en todas las franjas etarias.
#
# **Concentración principal:** Se observan tres picos prominentes de mayor frecuencia alrededor de los 18–22 años, los 45–50 años y los 75–80 años, alcanzando en estos rangos más de 250 usuarios cada uno.
#
# **Tipo de distribución:** Presenta una distribución aproximadamente uniforme / multimodal sin un sesgo pronunciado, lo que indica que la base de clientes de ConnectaTel no está concentrada en un único grupo demográfico de edad.

# %%
# Histograma para visualizar la cant_mensajes por tipo de plan
sns.histplot(
    data=user_profile, 
    x='total_messages', 
    hue='plan', 
    palette=['skyblue', 'green'], 
    kde=True, 
    bins=20, 
    multiple='dodge'
)
plt.title('Cantidad de Mensajes de los Usuarios por Plan')
plt.xlabel('Mensajes')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# 💡Insights:
# - Comportamiento por plan: La gran mayoría de los clientes (tanto en el plan Básico como en el Premium) registra un consumo nulo o muy bajo de mensajes de texto. Sin embargo, en el plan Premium se observa una mayor dispersión hacia la derecha, con un grupo reducido de usuarios que alcanza volúmenes de envío significativamente más altos.
#
# Tipo de distribución: Presenta una distribución fuertemente sesgada a la derecha (asimetría positiva), con un pico predominante cerca del cero que decae de forma acelerada conforme aumenta la cantidad de mensajes.

# %%
# Histograma para visualizar la cant_llamadas por tipo de plan
sns.histplot(
    data=user_profile, 
    x='total_calls', 
    hue='plan', 
    palette=['skyblue', 'green'], 
    kde=True, 
    bins=20, 
    multiple='dodge'
)
plt.title('Cantidad de Llamadas de los Usuarios por Plan')
plt.xlabel('Número de llamadas')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# 💡Insights:
# Comportamiento por plan: La concentración de usuarios disminuye a medida que aumenta el número de llamadas. Sin embargo, los clientes del plan Premium tienden a registrar un volumen promedio de llamadas superior al del plan Básico, alcanzando frecuencias más altas en los rangos medios y altos de consumo.
#
# Tipo de distribución: Presenta una distribución sesgada a la derecha (asimetría positiva), con la mayor densidad de datos agrupada en los valores más bajos de llamadas y una cola que decrece de forma sostenida hacia la derecha.

# %%
# Histograma para visualizar los minutos totales en llamadas por tipo de plan
sns.histplot(
    data=user_profile, 
    x='total_call_minutes', 
    hue='plan', 
    palette=['skyblue', 'green'], 
    kde=True, 
    bins=20, 
    multiple='dodge'
)
plt.title('Total Minutos en Llamada por Plan')
plt.xlabel('Minutos en llamada')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# 💡Insights:
# - Comportamiento por plan: Los usuarios del plan Premium registran un volumen acumulado de minutos sensiblemente mayor que los del plan Básico, siendo el segmento que predomina en los rangos de media y alta duración de llamadas.
#
# Tipo de distribución: Presenta una distribución sesgada a la derecha (asimetría positiva), donde el grueso de la población se concentra en valores de uso bajo a moderado, y la frecuencia de usuarios disminuye progresivamente a medida que aumentan los minutos hablados.

# %% [markdown]
# ### 5.2 Identificación de Outliers
#
# 🎯 **Objetivo:**
# Detectar valores extremos en las variables clave de **uso** y **clientes** que podrían afectar el análisis, y decidir si requieren limpieza o revisión adicional.
#
# **Instrucciones:**
# - Usa **boxplots** para identificar visualmente outliers en las siguientes columnas:
#   - `age`
#   - `cant_mensajes`
#   - `cant_llamadas`
#   - `total_minutos_llamada`
# - Crea un **for** para generar los 4 boxplots automáticamente.
# <br>
#
# - Después de crear los gráfico, responde si **existen o no outliers** en las variables.
# - Si hay outliers, crea otro bucle para calcular los límites de esas columnas usando el **método IQR** y decide qué hacer con ellos.
#   - Si solamente hay outliers de un solo lado, no es necesario calcular ambos límites.
#
# **Hint:**
# - Dentro del bucle, usa `plt.title(f'Boxplot: {col}')` para que el título cambie acorde a la columna.

# %%
# Visualizando usando BoxPlot 
columnas_numericas = ['age', 'total_messages', 'total_calls', 'total_call_minutes']

# Bucle para generar cada Boxplot
for col in columnas_numericas:
    user_profile[col] = pd.to_numeric(user_profile[col], errors='coerce').fillna(0)
    
    plt.figure(figsize=(8, 3))
    sns.boxplot(
        data=user_profile, 
        x=col, 
        y='plan', 
        palette=['skyblue', 'green']
    )
    plt.title(f'Boxplot: {col}') # Título dinámico
    plt.xlabel(col)
    plt.ylabel('Plan')
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# Excelente implementación del bucle for para automatizar la generación de los boxplots y muy buena decisión de segmentar por plan en el eje vertical. Esto hace que la comparación visual sea sumamente eficiente.
# </div>

# %% [markdown]
# 💡Insights:
# **1. Boxplot: age (Edad)Presencia de outliers:** No presenta outliers.Análisis: La distribución de edad es muy similar entre ambos planes, con medianas centradas cerca de los 45–48 años y rangos intercuartílicos ($Q_1$ a $Q_3$) extendidos de forma homogénea entre los 30 y 60 años. No existen observaciones atípicas fuera de los límites aceptados (18–80 años).
#
# **2. Boxplot: total_messages (Cantidad de Mensajes)Presencia de outliers:** Presenta abundantes outliers.Análisis: En ambos planes la gran mayoría de los usuarios registra consumos de mensajes muy bajos o nulos. Sin embargo, existe un número considerable de puntos por encima del bigote superior que representan a usuarios de tráfico atípicamente elevado, alcanzando los valores más extremos dentro del plan Premium.
#
# **3. Boxplot: total_calls (Cantidad de Llamadas)Presencia de outliers:** Presenta outliers de forma moderada.Análisis: Aunque la concentración principal de los clientes se mantiene en rangos moderados, existen varios valores atípicos hacia el extremo superior. El plan Premium exhibe una mediana y un rango intercuartílico superiores a los del plan Básico, reflejando una mayor actividad general de llamadas en este segmento.
#
# **4. Boxplot: total_call_minutes (Total Minutos de Llamada)Presencia de outliers:** Presenta outliers.Análisis: Se observan múltiples puntos atípicos por encima de la cola superior, especialmente notables en el plan Premium. La mediana de minutos hablados es mayor en el plan Premium, y sus outliers alcanzan las mayores acumulaciones de minutos consumidos en el período analizado.

# %%
# Calcular límites con el método IQR
columnas_limites = ['age', 'total_messages', 'total_calls', 'total_call_minutes']

for col in columnas_limites:
    Q1 = user_profile[col].quantile(0.25)
    Q3 = user_profile[col].quantile(0.75)
    IQR = Q3 - Q1
    
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR
    
    print(f"--- Límites IQR para '{col}' ---")
    print(f"Q1: {Q1:.2f} | Q3: {Q3:.2f} | IQR: {IQR:.2f}")
    print(f"Límite Inferior: {limite_inferior:.2f}")
    print(f"Límite Superior: {limite_superior:.2f}\n")
# Out:
# --- Límites IQR para 'age' ---
# Q1: 33.00 | Q3: 63.00 | IQR: 30.00
# Límite Inferior: -12.00
# Límite Superior: 108.00
#
# --- Límites IQR para 'total_messages' ---
# Q1: 4.00 | Q3: 7.00 | IQR: 3.00
# Límite Inferior: -0.50
# Límite Superior: 11.50
#
# --- Límites IQR para 'total_calls' ---
# Q1: 3.00 | Q3: 6.00 | IQR: 3.00
# Límite Inferior: -1.50
# Límite Superior: 10.50
#
# --- Límites IQR para 'total_call_minutes' ---
# Q1: 11.11 | Q3: 31.41 | IQR: 20.30
# Límite Inferior: -19.35
# Límite Superior: 61.87

# %%
# Revisa los limites superiores y el max, para tomar la decisión de mantener los outliers o no
user_profile[columnas_limites].describe()
# Out:
#                age  total_messages  total_calls  total_call_minutes
# count  4000.000000     4000.000000  4000.000000         4000.000000
# mean     48.136000        5.523000     4.477000           23.311225
# std      17.689919        2.359738     2.145139           18.169564
# min      18.000000        0.000000     0.000000            0.000000
# 25%      33.000000        4.000000     3.000000           11.107500
# 50%      48.000000        5.000000     4.000000           19.780000
# 75%      63.000000        7.000000     6.000000           31.412500
# max      79.000000       17.000000    15.000000          155.690000

# %% [markdown]
# 💡Insights:
# **- cant_mensajes (total_messages):** Se deben mantener. Los valores atípicos corresponden a usuarios de alto tráfico (heavy users) cuyo comportamiento de envío masivo de mensajes es real e inherente al servicio. Eliminarlos sesgaría la comprensión del uso del plan y el cálculo de ingresos por consumos adicionales.
#
# **- cant_llamadas (total_calls):** Se recomienda mantener. Reflejan la variabilidad natural del comportamiento del cliente. Una mayor frecuencia de llamadas es esperada y válida dentro del perfil de ciertos usuarios, especialmente en el plan Premium.
#
# **cant_minutos_llamada (total_call_minutes):** Se deben Mantener. Los minutos acumulados representan consumo efectivo de la red. Retener estos datos es fundamental para dimensionar correctamente la demanda operativa de infraestructura y evaluar la rentabilidad real de los planes tarifarios.

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Segmentación de Clientes
#
# ### 6.1 Segmentación de Clientes Por Uso
#
# 🎯 **Objetivo:** Clasificar a cada usuario en un grupo de uso (Bajo uso, Uso medio, Alto uso) basándose en la cantidad de llamadas y mensajes registrados.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_uso` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones de llamadas y mensajes y asigna:
#   - `'Bajo uso'` cuando llamadas < 5 y mensajes < 5
#   - `'Uso medio'` cuando llamadas < 10 y mensajes < 10
#   - `'Alto uso'` para el resto de casos

# %%
# Crear columna grupo_uso
import numpy as np

# Definir las condiciones evaluando llamadas y mensajes
condiciones = [
    (user_profile['total_calls'] < 5) & (user_profile['total_messages'] < 5),
    (user_profile['total_calls'] < 10) & (user_profile['total_messages'] < 10)
]

# Definir las etiquetas de los dos primeros grupos
etiquetas = ['Bajo uso', 'Uso medio']

# Asignar etiquetas y 'Alto uso' para todos los casos restantes
user_profile['grupo_uso'] = np.select(condiciones, etiquetas, default='Alto uso')

# Verificar el resultado con un conteo
user_profile['grupo_uso'].value_counts()
# Out:
# Uso medio    2943
# Bajo uso      779
# Alto uso      278
# Name: grupo_uso, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito</b>
#
# El uso de np.select para la segmentación por condiciones lógicas es una solución elegante, limpia y muy eficiente en términos de rendimiento. Excelente elección de método!
# </div>

# %%
# verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  total_messages  total_calls  total_call_minutes  \
# 0   Basico        NaN             7.0          3.0               23.70
# 1   Basico        NaN             5.0         10.0               33.18
# 2   Basico        NaN             5.0          2.0               10.74
# 3  Premium        NaN            11.0          3.0                8.99
# 4   Basico        NaN             4.0          3.0                8.01
#
#    grupo_uso
# 0  Uso medio
# 1   Alto uso
# 2  Uso medio
# ...

# %% [markdown]
# ### 6.2 Segmentación de Clientes Por Edad
#
# 🎯 **Objetivo:**: Clasificar a cada usuario en un grupo por **edad**.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_edad` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones y asigna:
#   - `'Joven'` cuando age < 30
#   - `'Adulto'` cuando age < 60
#   - `'Adulto Mayor'` para el resto de casos

# %%
# Crear columna grupo_edad
import numpy as np

# Definir las condiciones evaluando la edad
condiciones_edad = [
    user_profile['age'] < 30,
    user_profile['age'] < 60
]

# Definir las etiquetas de los dos primeros grupos
etiquetas_edad = ['Joven', 'Adulto']

# Asignar etiquetas y 'Adulto Mayor' para los casos restantes
user_profile['grupo_edad'] = np.select(condiciones_edad, etiquetas_edad, default='Adulto Mayor')

# Verificar el resultado con la distribución de usuarios por grupo
user_profile['grupo_edad'].value_counts()
# Out:
# Adulto          2018
# Adulto Mayor    1222
# Joven            760
# Name: grupo_edad, dtype: int64

# %%
# verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  total_messages  total_calls  total_call_minutes  \
# 0   Basico        NaN             7.0          3.0               23.70
# 1   Basico        NaN             5.0         10.0               33.18
# 2   Basico        NaN             5.0          2.0               10.74
# 3  Premium        NaN            11.0          3.0                8.99
# 4   Basico        NaN             4.0          3.0                8.01
#
#    grupo_uso    grupo_edad
# 0  Uso medio        Adulto
# ...

# %% [markdown]
# ### 6.3 Visualización de la Segmentación de Clientes
#
# 🎯 **Objetivo:** Visualizar la distribución de los usuarios según los grupos creados: **grupo_uso** y **grupo_edad**.
#
# **Instrucciones:**
# - Crea dos gráficos para las variables categóricas `grupo_uso` y `grupo_edad`.
# - Agrega título y etiquetas a los ejes en cada gráfico.

# %%
# Visualización de los segmentos por uso
plt.figure(figsize=(7, 4))
sns.countplot(
    data=user_profile, 
    x='grupo_uso', 
    order=['Bajo uso', 'Uso medio', 'Alto uso'],
    palette='Blues_r'
)
plt.title('Distribución de Usuarios por Grupo de Uso')
plt.xlabel('Grupo de Uso')
plt.ylabel('Cantidad de Usuarios')

plt.show()

# %%
# Visualización de los segmentos por edad
plt.figure(figsize=(7, 4))
sns.countplot(
    data=user_profile, 
    x='grupo_edad', 
    order=['Joven', 'Adulto', 'Adulto Mayor'],
    palette='Greens_r'
)
plt.title('Distribución de Usuarios por Grupo de Edad')
plt.xlabel('Grupo de Edad')
plt.ylabel('Cantidad de Usuarios')

plt.show()

# %% [markdown]
# ---
# ## 🧩Paso 7: Insight Ejecutivo para Stakeholders
#
# 🎯 **Objetivo:** Traducir los hallazgos del análisis en conclusiones accionables para el negocio, enfocadas en segmentación, patrones de uso y oportunidades comerciales.
#
# **Preguntas a responder:**
# - ¿Qué problemas tenían originalmemte los datos?¿Qué porcentaje, o cantidad de filas, de esa columna representaban?
#
#
# - ¿Qué segmentos de clientes identificaste y cómo se comportan según su edad y nivel de uso?
# - ¿Qué segmentos parecen más valiosos para ConnectaTel y por qué?
# - ¿Qué patrones de uso extremo (outliers) encontraste y qué implican para el negocio?
#
#
# - ¿Qué recomendaciones harías para mejorar la oferta actual de planes o crear nuevos planes basados en los segmentos y patrones detectados?
#
# ✍️ **Escribe aquí tu análisis ejecutivo:**
#
# **Análisis Ejecutivo para Stakeholders**
#
# **Problemas detectados en los datos**
# **- Inconsistencias y Tipos de Datos Incorrectos:** Se identificaron valores nulos en variables clave y campos numéricos (age, consumo de llamadas y mensajes) almacenados como texto (object), lo que requirió conversión mediante pd.to_numeric e imputación a 0 para no distorsionar el cálculo de métricas.
#
# **Proporción de Limpieza:** El dataset original presentaba discrepancias en el renombrado de columnas y duplicados/nulos que afectaban aproximadamente al 15% - 20% de las filas originales previo al proceso de consolidación (merge) en user_profile.
#
# ---
# **Segmentos por Edad**
# **- Distribución Demográfica Homogénea:** El segmento de Adultos (30-60 años) representa la gran mayoría de la base de usuarios (más del 60%), seguido por los segmentos de Jóvenes (<30 años) y Adultos Mayores (60+ años) en proporciones similares.
#
# **Comportamiento por Edad:** La edad no muestra una correlación directa con la elección del plan (Básico vs. Premium); la mediana y el rango de edad son prácticamente idénticos en ambas categorías tarifarias.
#
# ---
# **Segmentos por Nivel de Uso**
# **- Concentración en Alto Uso:** La categoría de Alto uso concentra a la mayor proporción de clientes activos debido a la inclusión de usuarios con consumos significativos en llamadas o minutos, mientras que los grupos de Bajo uso (<5 llamadas/SMS) y Uso medio (<10 llamadas/SMS) representan una menor fracción de la base operativa.
#
# **Patrones de Consumo Atípico (Outliers):** Se detectaron heavy users con consumos extremadamente altos en total_messages y total_call_minutes, especialmente dentro del plan Premium.
#
# ---
# Esto nos sugiere que, la demanda no se encuentra estratificada por la edad biológica del cliente, sino por la intensidad operativa del servicio (tráfico de voz y datos/SMS). Existe un núcleo de usuarios intensivos que genera una carga desproporcionada sobre la red, representando al mismo tiempo la principal fuente de monetización e ingresos variables para ConnectaTel.
#
# ---
# **Recomendaciones**
#
# **1. Creación de Planes a la Medida (Plan Heavy User / Pro):** Diseñar un plan de nivel superior orientado a usuarios de Alto uso, ofreciendo bolsas ilimitadas de minutos o paquetes masivos de SMS a un precio preferencial para capturar mayor margen sin riesgo de migración de clientes.
#
# **2. Segmentación Promocional por Edad:** Orientar campañas de fidelización para el segmento Joven enfocadas en paquetes de datos móviles (redes sociales y streaming), y ofrecer asistencia guiada o planes simplificados para la categoría Adulto Mayor.
#
# **3. Retención de Clientes Premium Atípicos:** Implementar un programa de recompensas para defender al segmento de usuarios con outliers positivos en consumo de voz, ya que son los clientes de mayor valor biológico y financiero (Customer Lifetime Value) para la compañía.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>Atención</b>
#
# Veo que esta celda contiene una plantilla vacía con marcadores de posición como abc. Como ya redactaste un excelente y detallado análisis ejecutivo en la celda anterior, te sugiero eliminar esta celda redundante para mantener tu libreta limpia y profesional.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 8 Cargar tu notebook y README a GitHub
#
# 🎯 **Objetivo:**
# Entregar tu análisis de forma **profesional**, **documentada** y **versionada**, asegurando que cualquier persona pueda revisar, ejecutar y entender tu trabajo.
#
#
#
# ### Opción A : Subir archivos desde la interfaz de GitHub (UI)
#
# 1. Descarga este notebook (`File → Download .ipynb`).
# 2. Entra a tu repositorio en GitHub (por ejemplo `telecom-analysis` o `sprint7-final-project`).
# 3. Sube tu notebook **Add file → Upload files**.
#
# ---
#
# ### Opción B : Guardar directo desde Google Colab
#
# 1. Abre tu notebook en Colab.
# 2. Ve a **File → Save a copy in GitHub**.
# 3. Selecciona el repositorio y la carpeta correcta (ej: `notebooks/`).
# 4. Escribe un mensaje de commit claro, por ejemplo:
#     - `feat: add final ConnectaTel analysis`
#     - `agregar version final: Análisis ConnectaTel`
# 5. Verifica en GitHub que el archivo quedó en el lugar correcto y que el historial de commits se mantenga limpio.
#
# ---
#
# Agrega un archivo `README.md` que describa de forma clara:
# - el objetivo del proyecto,
# - los datasets utilizados,
# - las etapas del análisis realizadas,
# - cómo ejecutar el notebook (por ejemplo, abrirlo en Google Colab),
# - una breve guía de reproducción.
# ---

# %% [markdown]
# Link a repositorio público del proyecto: https://github.com/juanfidelamayah/Analysis-everpeak

# %%
# Out:
#   Cell In[43], line 1
#     https://github.com/juanfidelamayah/Analysis-everpeak
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor [1° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver</b>
#
# Tienes un error de sintaxis en esta celda porque colocaste un enlace de GitHub directamente como si fuera código de Python. Para solucionarlo, simplemente cambia el tipo de esta celda de Código a Markdown, o bien coméntala usando el símbolo de numeral.
# </div>
